# %%
# importing necessary Python extensions programs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import pandas_datareader
import datetime
import os
os.listdir('./Data/')
# Out:
# ['.ipynb_checkpoints',
#  'EducationDATA.xlsx',
#  'GDPDATA.xlsx',
#  '~$EducationDATA.xlsx',
#  '~$GDPDATA.xlsx']

# %%
# Defining data
gdp = 'data/GDPDATA.xlsx'
edu = 'data/EDUCATIONDATA.xlsx'

# %%
# cleaning rows
GDP = pd.read_excel(gdp, skiprows = 3)

# %%
# cleaning columns
Drop_these = ['Indicator Code','Country Code','Indicator Name','1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998','2016','2017','2018']
GDP.drop(Drop_these, axis = 1, inplace = True) # Axis 1 = columns

# %%
# Drop all rows with NaN values
GDP.dropna()
# Out:
#                                           Country Name       1999       2000  \
# 0                                                Aruba   1.238039   7.616590
# 2                                               Angola   2.181490   3.054624
# 3                                              Albania  12.890000   6.950000
# 4                                              Andorra   4.099081   3.528361
# 5                                           Arab World   1.851039   5.463191
# 6                                 United Arab Emirates   2.902214  10.852704
# 7                                            Argentina  -3.385457  -0.788999
# 8                                              Armenia   3.300000   5.900000
# 10                                 Antigua and Barbuda   3.707895   6.691739
# 11                                           Australia   5.018064   3.943189
# 12                                             Austria   3.556330   3.375722
# ...
